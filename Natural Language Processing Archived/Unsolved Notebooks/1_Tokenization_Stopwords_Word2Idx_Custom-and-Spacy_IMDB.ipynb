# %%
from IPython.display import clear_output

# %%
# %pip install torch torchtext tqdm import spacy


# %pip install --upgrade portalocker

clear_output()

# %%
import string

import torch
from torchtext.datasets import IMDB
from tqdm import tqdm

# %% [markdown]
# # Content
#
# In this notebook, you'll implement ways to process text for it to be used in machine learning/deep learning models. Specifically:
#
# 1. Removing Stop words from the text
# 2. Tokenizing the text
# 3. Converting the text to numerical form to be used by models

# %% [markdown]
# ## Downloading the Dataset
#
# We will work with the IMDB review dataset
#
# It's a sentiment analysis dataset which is built using labelling IMDB reviews of movies as positive or negative

# %%
# Download and load the IMDB dataset
train_data = IMDB(split=('train'))

# %% [markdown]
# ## Custom text processing functions
#
# First, we will take a look at how we can manually(without NLP libraries) write functions for tokenization etc.

# %%
# Define a function to remove punctuation.
def remove_punctuation(text):
    pass

# Define a function to remove stop words
def remove_stopwords(text):
    pass

# Define a function to Tokenize the text. A possible way you can do this is splitting over white space or using regex.
def tokenize(text):
    pass

# %% [markdown]
# ## Processing the IMDB dataset
#
# To save time, You can use a small part of dataset instead of the whole dataset
#
# 1. Use the functions you made above to clean and tokenize the text(you might also want to convert your text to lower or upper case to remove case sensitive duplicates)
# 2. create a word to idx and an idx to word mapping(you can use dictionaries for this)
# 3. Take an example text, clean and tokenize it and then convert it into numerical form. Show the text, tokens and the numerical form

# %% [markdown]
# ## Using Spacy
#
# Now, implement the functions again but this time use spacy instead of making the functions yourself.

# %%
# import spacy and load it's english modules

# %% [markdown]
# ### Define spacy functions

# %%
def remove_stopwords_sp(text):  # _sp to keep it seperate from our own implementation.
    pass

def tokenize_sp(text):
    pass

# no need to remove punctuations as spacy will automatically seperate punctuations characters into seperate tokens

# %% [markdown]
# ### Process text with spacy functions
#
# once again, Process the text but this time use spacy functions
#
# 1. Clean and tokenize the text
# 2. create a word to idx and an idx to word mapping
# 3. Take an example text(try to take one with punctuations), clean and tokenize it and then convert it into numerical form. Show the text, tokens and the numerical form
